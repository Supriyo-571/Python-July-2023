# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1, 2, 3, 4, 5]
h = [10, 8, 12, 4, 7]
c = ['red', 'yellow', 'black', 'blue', 'orange']
import matplotlib.pyplot as plt


plt.bar(x, height = h, color = c)

plt.show()
